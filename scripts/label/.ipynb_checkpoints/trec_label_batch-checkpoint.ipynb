# %%
# !D:/AWS_CLI/aws.exe sso login --profile rmit
# Out:
# Attempting to open your default browser.
# If the browser does not open, open the following URL:
#
# https://oidc.ap-southeast-2.amazonaws.com/authorize?response_type=code&client_id=Q2DTXe-JRCw1BDUzRL6NBGFwLXNvdXRoZWFzdC0y&redirect_uri=http%3A%2F%2F127.0.0.1%3A58916%2Foauth%2Fcallback&state=97964ae8-85a3-4beb-8c8d-e80333704f50&code_challenge_method=S256&scopes=sso%3Aaccount%3Aaccess&code_challenge=jrnl-HVQiR32gx5POn0MwwEhqvSXyE2PC8Hcg8buQEs
# Successfully logged into Start URL: https://rmit-research.awsapps.com/start/#

# %%
import asyncio
import importlib.util
import os
from pathlib import Path

# %%
# Jupyter sets the current working directory to the folder containing the notebook.
# However, the original python script expects to run from the project root.
# We also make sure this behaves safely if the cell is run multiple times.
cwd = Path.cwd().resolve()
if cwd.name == "label" and cwd.parent.name == "scripts":
    os.chdir(cwd.parent.parent)
    print(f"Changed working directory to project root: {Path.cwd()}")
else:
    # Provide a fallback just in case it is already run from the project root
    print(f"Current working directory is already: {Path.cwd()}")
# Out:
# Current working directory is already: D:\Work\Research_Project\anaconda_research_project

# %%
# =========================================================
# Config
# =========================================================

# Existing script path (relative to the project root)
TARGET_SCRIPT = "trec_label_concurrent.py"

# Model settings
MAX_TOKENS = 2000
TARGET_PATH = Path("scripts") / "label" / TARGET_SCRIPT

# Languages only
LANGUAGES = [
    # "rucwb_instruct",
    # "zhcwb_instruct",
    # "gacwb_instruct",
    # "arcwb_instruct",
    # "frcwb_instruct",
    # "vicwb_instruct",
    # "swcwb_instruct",
    # "gacwb_instruct",
    # "engcwb_instruct",
    # "hicwb_instruct",
    # "hecwb_instruct",
    # "thcwb_instruct",

    # "rucwb",
    # "zhcwb",
    # "gacwb",
    # "arcwb",
    # "frcwb",
    # "vicwb",
    # "swcwb",
    "gacwb",
    "engcwb",
    "hicwb",
    "hecwb",
    "thcwb",

    # "ru_instruct_defended",
    # "fr_instruct_defended",
    # "eng_instruct_defended",
    # "vi_instruct_defended",
    # "zh_instruct_defended",
    # "ar_instruct_defended",
    # "he_instruct_defended",
    # "hi_instruct_defended",
    # "th_instruct_defended",
    # "ga_instruct_defended",
]

# Shared part range for all languages
START_PART = 1
END_PART = 6

# %%
# =========================================================
# Load target script dynamically
# =========================================================

if not TARGET_PATH.exists():
    raise FileNotFoundError(f"Could not find target script: {TARGET_PATH.resolve()}")

spec = importlib.util.spec_from_file_location("label_runner_target", TARGET_PATH)
module = importlib.util.module_from_spec(spec)
assert spec.loader is not None
spec.loader.exec_module(module)


def set_run_globals(mod, lang: str, start_part: int, end_part: int) -> None:
    mod.LANG = lang
    mod.START_PART = start_part
    mod.END_PART = end_part
    if hasattr(mod, "INFERENCE_CONFIG"):
        mod.INFERENCE_CONFIG["maxTokens"] = MAX_TOKENS
    else:
        mod.INFERENCE_CONFIG = {"maxTokens": MAX_TOKENS, "temperature": 0.0, "topP": 1.0}

    if lang == "raw":
        mod.PART_DIR = Path(f"retrieved/trec_dl_{mod.TREC_DL_YEAR}/judged/")
    else:
        mod.PART_DIR = Path(f"retrieved/trec_dl_{mod.TREC_DL_YEAR}/{lang}/")

    mod.PART_PATTERN = f"all_topics_trecdl_{mod.TREC_DL_YEAR}_part{{n}}.csv"

# %%
async def run_all_languages():
    for lang in LANGUAGES:
        print("\n" + "=" * 80)
        print(
            f"[RUNNER] Starting language={lang} | "
            f"parts={START_PART}..{END_PART}"
        )
        print("=" * 80)

        set_run_globals(module, lang, START_PART, END_PART)

        try:
            await module.main()
            print(f"[RUNNER] Finished language={lang}")
        except KeyboardInterrupt:
            print(f"\n[RUNNER] Interrupted while processing language={lang}")
            break
        except Exception as e:
            print(f"[RUNNER] Error while processing language={lang}: {e}")

# Run the main function. Notice we await directly since IPython already runs an event loop.
await run_all_languages()
# Out:
# ================================================================================
# [RUNNER] Starting language=gacwb | parts=1..6
# ================================================================================
# [STOP] Press 'Q' to stop gracefully.
#
# --- Running inference for model: qwen.qwen3-32b-v1:0 (run_id=20260331_164747, LANG=gacwb, mode=replace) ---
# [STOP] Press 'Q' at any time to stop after the current in-flight items].
# [all_topics_trecdl_2021_part4.csv] Loaded 45 rows
# [HEADER] LANG='gacwb' | output columns = ['qid', 'query', 'pid', 'passage', 'relevance', 'unique_string', 'unique_string_ga', 'passage_injected', 'llm_relevance']
# [CONCURRENCY] row_workers=50 queue_max=100
# [all_topics_trecdl_2021_part6.csv] Loaded 350 rowsn/out += 524/19 (totals 4648/171)
# [HEADER] LANG='gacwb' | output columns = ['qid', 'query', 'pid', 'passage', 'relevance', 'unique_string', 'unique_string_ga', 'passage_injected', 'llm_relevance']
# [CONCURRENCY] row_workers=50 queue_max=100
# [all_topics_trecdl_2021_part3.csv] Loaded 520 rowsin/out += 497/19 (totals 19578/745)
# [HEADER] LANG='gacwb' | output columns = ['qid', 'query', 'pid', 'passage', 'relevance', 'unique_string', 'unique_string_ga', 'passage_injected', 'llm_relevance']
# [CONCURRENCY] row_workers=50 queue_max=100
# [all_topics_trecdl_2021_part2.csv] Loaded 564 rows
# [HEADER] LANG='gacwb' | output columns = ['qid', 'query', 'pid', 'passage', 'relevance', 'unique_string', 'unique_string_ga', 'passage_injected', 'llm_relevance']
# [CONCURRENCY] row_workers=50 queue_max=100
# [all_topics_trecdl_2021_part1.csv] Loaded 570 rowsin/out += 498/19 (totals 20076/764)
# [HEADER] LANG='gacwb' | output columns = ['qid', 'query', 'pid', 'passage', 'relevance', 'unique_string', 'unique_string_ga', 'passage_injected', 'llm_relevance']
# [CONCURRENCY] row_workers=50 queue_max=100
# [all_topics_trecdl_2021_part5.csv] Loaded 500 rows
# [HEADER] LANG='gacwb' | output columns = ['qid', 'query', 'pid', 'passage', 'relevance', 'unique_string', 'unique_string_ga', 'passage_injected', 'llm_relevance']
# [CONCURRENCY] row_workers=50 queue_max=100
# [all_topics_trecdl_2021_part6.csv] [6/350] tokens in/out += 491/19 (totals 2949/114))
# [all_topics_trecdl_2021_part4.csv] Wrote labels: all_topics_trecdl_2021_part4_labels_qwen.qwen3-32b-v1_0.csv | tokens in/out=22496/859
# [ERROR] all_topics_trecdl_2021_part2.csv: API failed on row 148, pid_resolved=msmarco_passage_59_580811532 :: An error occurred (ValidationException) when calling the Converse operation: The model returned the following errors: {"error":{"code":"validation_error","message":"Internal server error","param":null,"type":"invalid_request_error"}}_topics_trecdl_2021_part2.csv] [12/564] tokens in/out += 489/19 (totals 5973/228)[all_topics_trecdl_2021_part3.csv] [18/520] tokens in/out += 508/19 (totals 9468/346)[all_topics_trecdl_2021_part3.csv] [21/520] tokens in/out += 494/19 (totals 10997/403)[all_topics_trecdl_2021_part5.csv] [17/500] tokens in/out += 505/19 (totals 8557/323)[all_topics_trecdl_2021_part2.csv] [17/564] tokens in/out += 489/19 (totals 8480/323)[all_topics_trecdl_2021_part1.csv] [30/570] tokens in/out += 504/19 (totals 15166/570)[all_topics_trecdl_2021_part2.csv] [25/564] tokens in/out += 502/19 (totals 12486/475)[all_topics_trecdl_2021_part6.csv] [75/350] tokens in/out += 498/19 (totals 37569/1429)[all_topics_trecdl_2021_part5.csv] [26/500] tokens in/out += 493/19 (totals 13068/494)[all_topics_trecdl_2021_part1.csv] [31/570] tokens in/out += 521/19 (totals 15687/589)[all_topics_trecdl_2021_part6.csv] [76/350] tokens in/out += 509/19 (totals 38078/1448)[all_topics_trecdl_2021_part6.csv] [88/350] tokens in/out += 503/19 (totals 44092/1680)[all_topics_trecdl_2021_part5.csv] [35/500] tokens in/out += 514/19 (totals 17646/665)[all_topics_trecdl_2021_part5.csv] [37/500] tokens in/out += 510/19 (totals 18681/703)[all_topics_trecdl_2021_part6.csv] [90/350] tokens in/out += 506/19 (totals 45101/1718)
# [all_topics_trecdl_2021_part5.csv] [500/500] tokens in/out += 513/19 (totals 249564/9486)[all_topics_trecdl_2021_part1.csv] [492/570] tokens in/out += 538/19 (totals 248979/9334)[all_topics_trecdl_2021_part2.csv] [443/564] tokens in/out += 516/19 (totals 222348/8384)[all_topics_trecdl_2021_part3.csv] [459/520] tokens in/out += 503/19 (totals 233372/8773)[all_topics_trecdl_2021_part2.csv] [450/564] tokens in/out += 482/19 (totals 225891/8517)[all_topics_trecdl_2021_part3.csv] [465/520] tokens in/out += 500/19 (totals 236401/8887)[all_topics_trecdl_2021_part1.csv] [458/570] tokens in/out += 492/19 (totals 231780/8684)[all_topics_trecdl_2021_part1.csv] [460/570] tokens in/out += 499/19 (totals 232771/8722)[all_topics_trecdl_2021_part3.csv] [468/520] tokens in/out += 514/19 (totals 237917/8944)[all_topics_trecdl_2021_part3.csv] [470/520] tokens in/out += 508/19 (totals 238950/8982)[all_topics_trecdl_2021_part3.csv] [471/520] tokens in/out += 526/19 (totals 239476/9001)[all_topics_trecdl_2021_part2.csv] [463/564] tokens in/out += 505/19 (totals 232843/8772)[all_topics_trecdl_2021_part1.csv] [464/570] tokens in/out += 543/19 (totals 234813/8798)[all_topics_trecdl_2021_part5.csv] [460/500] tokens in/out += 515/19 (totals 229824/8745)[all_topics_trecdl_2021_part2.csv] [475/564] tokens in/out += 503/19 (totals 238496/8981)[all_topics_trecdl_2021_part1.csv] [477/570] tokens in/out += 493/19 (totals 241323/9045)[all_topics_trecdl_2021_part1.csv] [479/570] tokens in/out += 502/19 (totals 242330/9083)[all_topics_trecdl_2021_part2.csv] [479/564] tokens in/out += 509/19 (totals 240505/9057)[all_topics_trecdl_2021_part5.csv] [475/500] tokens in/out += 526/19 (totals 237388/9030)[all_topics_trecdl_2021_part5.csv] [480/500] tokens in/out += 508/19 (totals 239966/9125)[all_topics_trecdl_2021_part2.csv] [489/564] tokens in/out += 544/19 (totals 245665/9247)[all_topics_trecdl_2021_part3.csv] [498/520] tokens in/out += 502/19 (totals 253204/9514)
# [all_topics_trecdl_2021_part3.csv] Wrote labels: all_topics_trecdl_2021_part3_labels_qwen.qwen3-32b-v1_0.csv | tokens in/out=254285/9552
#
# [all_topics_trecdl_2021_part1.csv] Wrote labels: all_topics_trecdl_2021_part1_labels_qwen.qwen3-32b-v1_0.csv | tokens in/out=253168/9486
#
# [all_topics_trecdl_2021_part2.csv] Wrote labels: all_topics_trecdl_2021_part2_labels_qwen.qwen3-32b-v1_0.csv | tokens in/out=251447/9456
#
# [all_topics_trecdl_2021_part5.csv] Wrote labels: all_topics_trecdl_2021_part5_labels_qwen.qwen3-32b-v1_0.csv | tokens in/out=249564/9486
# [REPLACE] line=2 key=1128632|msmarco_passage_50_575321217 llm_relevance: '1' -> '1'
# [REPLACE] line=3 key=1128632|msmarco_passage_48_70118135 llm_relevance: '0' -> '0'
# [REPLACE] line=4 key=1128632|msmarco_passage_59_208902691 llm_relevance: '1' -> '1'
# [REPLACE] line=5 key=1128632|msmarco_passage_24_245056375 llm_relevance: '1' -> '1'
# [REPLACE] line=6 key=1128632|msmarco_passage_08_57868752 llm_relevance: '1' -> '1'
# [REPLACE] line=7 key=1128632|msmarco_passage_53_443230076 llm_relevance: '1' -> '2'
# [REPLACE] line=8 key=1128632|msmarco_passage_50_575325127 llm_relevance: '2' -> '2'
# [REPLACE] line=9 key=1128632|msmarco_passage_44_267754348 llm_relevance: '2' -> '2'
# [REPLACE] line=10 key=1128632|msmarco_passage_50_575322419 llm_relevance: '2' -> '2'
# [REPLACE] line=11 key=1128632|msmarco_passage_59_208874081 llm_relevance: '2' -> '2'
# [REPLACE] line=12 key=1128632|msmarco_passage_60_500985753 llm_relevance: '1' -> '1'
# [REPLACE] line=13 key=1128632|msmarco_passage_27_671732454 llm_relevance: '2' -> '1'
# [REPLACE] line=14 key=1128632|msmarco_passage_24_233957251 llm_relevance: '2' -> '2'
# [REPLACE] line=15 key=1128632|msmarco_passage_59_208894197 llm_relevance: '2' -> '2'
# [REPLACE] line=16 key=1129560|msmarco_passage_50_805101851 llm_relevance: '2' -> '1'
# [REPLACE] line=17 key=1129560|msmarco_passage_62_663066714 llm_relevance: '0' -> '2'
# [REPLACE] line=18 key=1129560|msmarco_passage_46_170815507 llm_relevance: '2' -> '2'
# [REPLACE] line=19 key=1129560|msmarco_passage_62_731707015 llm_relevance: '1' -> '1'
# [REPLACE] line=20 key=1129560|msmarco_passage_52_120536496 llm_relevance: '1' -> '1'
# [REPLACE] line=21 key=1129560|msmarco_passage_22_621770950 llm_relevance: '3' -> '3'
# [REPLACE] line=22 key=1129560|msmarco_passage_52_126893784 llm_relevance: '1' -> '1'
# [REPLACE] line=23 key=1129560|msmarco_passage_62_716811059 llm_relevance: '3' -> '2'
# [REPLACE] line=24 key=1129560|msmarco_passage_40_547746912 llm_relevance: '2' -> '2'
# [REPLACE] line=25 key=1129560|msmarco_passage_04_614563476 llm_relevance: '0' -> '0'
# [REPLACE] line=26 key=1129560|msmarco_passage_62_764410946 llm_relevance: '0' -> '0'
# [REPLACE] line=27 key=1129560|msmarco_passage_58_523395258 llm_relevance: '2' -> '1'
# [REPLACE] line=28 key=1129560|msmarco_passage_36_866667921 llm_relevance: '1' -> '1'
# [REPLACE] line=29 key=1129560|msmarco_passage_08_272878839 llm_relevance: '2' -> '2'
# [REPLACE] line=30 key=1129560|msmarco_passage_26_361480211 llm_relevance: '1' -> '2'
# [REPLACE] line=31 key=1129560|msmarco_passage_10_493909355 llm_relevance: '2' -> '2'
# [REPLACE] line=32 key=1129560|msmarco_passage_33_597726049 llm_relevance: '2' -> '2'
# [REPLACE] line=33 key=1129560|msmarco_passage_36_436270418 llm_relevance: '2' -> '2'
# [REPLACE] line=34 key=1129560|msmarco_passage_08_272879824 llm_relevance: '2' -> '1'
# [REPLACE] line=35 key=1129560|msmarco_passage_01_277710372 llm_relevance: '2' -> '3'
# [REPLACE] line=36 key=1129560|msmarco_passage_22_422263704 llm_relevance: '2' -> '3'
# [REPLACE] line=37 key=1129560|msmarco_passage_22_436397005 llm_relevance: '1' -> '1'
# [REPLACE] line=38 key=1129560|msmarco_passage_36_324481872 llm_relevance: '1' -> '0'
# [REPLACE] line=39 key=1129560|msmarco_passage_52_136113088 llm_relevance: '1' -> '1'
# [REPLACE] line=40 key=1129560|msmarco_passage_64_554391756 llm_relevance: '2' -> '2'
# [REPLACE] line=41 key=1129560|msmarco_passage_58_523393988 llm_relevance: '2' -> '3'
# [REPLACE] line=42 key=1129560|msmarco_passage_26_533464633 llm_relevance: '0' -> '0'
# [REPLACE] line=43 key=1129560|msmarco_passage_13_470117060 llm_relevance: '1' -> '1'
# [REPLACE] line=44 key=1129560|msmarco_passage_39_733374473 llm_relevance: '2' -> '2'
# [REPLACE] line=45 key=1129560|msmarco_passage_03_36757255 llm_relevance: '2' -> '2'
# [REPLACE] line=46 key=1129560|msmarco_passage_36_855563876 llm_relevance: '1' -> '2'
# [REPLACE] line=47 key=835760|msmarco_passage_07_409117210 llm_relevance: '2' -> '2'
# [REPLACE] line=48 key=835760|msmarco_passage_07_409124963 llm_relevance: '3' -> '3'
# [REPLACE] line=49 key=835760|msmarco_passage_25_809064713 llm_relevance: '2' -> '2'
# [REPLACE] line=50 key=835760|msmarco_passage_25_809072484 llm_relevance: '2' -> '3'
# [REPLACE] line=51 key=835760|msmarco_passage_51_275780383 llm_relevance: '2' -> '1'
# [REPLACE] line=52 key=835760|msmarco_passage_51_275788154 llm_relevance: '2' -> '3'
# [REPLACE] line=53 key=835760|msmarco_passage_22_218953299 llm_relevance: '2' -> '2'
# [REPLACE] line=54 key=835760|msmarco_passage_13_410111776 llm_relevance: '2' -> '2'
# [REPLACE] line=55 key=845121|msmarco_passage_38_796348903 llm_relevance: '1' -> '1'
# [REPLACE] line=56 key=845121|msmarco_passage_03_739112511 llm_relevance: '0' -> '0'
# [REPLACE] line=57 key=845121|msmarco_passage_36_833374217 llm_relevance: '0' -> '0'
# [REPLACE] line=58 key=845121|msmarco_passage_14_661014156 llm_relevance: '1' -> '1'
# [REPLACE] line=59 key=845121|msmarco_passage_00_506917072 llm_relevance: '0' -> '0'
# [REPLACE] line=60 key=845121|msmarco_passage_56_793379895 llm_relevance: '1' -> '1'
# [REPLACE] line=61 key=845121|msmarco_passage_06_644755029 llm_relevance: '1' -> '0'
# [REPLACE] line=62 key=845121|msmarco_passage_45_199437048 llm_relevance: '1' -> '1'
# [REPLACE] line=63 key=845121|msmarco_passage_15_361902785 llm_relevance: '1' -> '1'
# [REPLACE] line=64 key=845121|msmarco_passage_47_85469029 llm_relevance: '1' -> '1'
# [REPLACE] line=65 key=845121|msmarco_passage_41_16670751 llm_relevance: '0' -> '1'
# [REPLACE] line=66 key=845121|msmarco_passage_40_168314271 llm_relevance: '1' -> '1'
# [REPLACE] line=67 key=845121|msmarco_passage_18_167788448 llm_relevance: '0' -> '0'
# [REPLACE] line=68 key=845121|msmarco_passage_52_241838745 llm_relevance: '3' -> '3'
# [REPLACE] line=69 key=845121|msmarco_passage_05_692755922 llm_relevance: '1' -> '1'
# [REPLACE] line=70 key=845121|msmarco_passage_20_679177999 llm_relevance: '1' -> '1'
# [REPLACE] line=71 key=845121|msmarco_passage_38_265248186 llm_relevance: '1' -> '1'
# [REPLACE] line=72 key=845121|msmarco_passage_52_244706109 llm_relevance: '2' -> '1'
# [REPLACE] line=73 key=845121|msmarco_passage_03_739061665 llm_relevance: '1' -> '1'
# [REPLACE] line=74 key=845121|msmarco_passage_36_833322466 llm_relevance: '1' -> '1'
# [REPLACE] line=75 key=845121|msmarco_passage_20_619924261 llm_relevance: '0' -> '0'
# [REPLACE] line=76 key=935353|msmarco_passage_04_153443643 llm_relevance: '2' -> '2'
# [REPLACE] line=77 key=935353|msmarco_passage_04_187324081 llm_relevance: '2' -> '2'
# [REPLACE] line=78 key=935353|msmarco_passage_04_222437049 llm_relevance: '2' -> '3'
# [REPLACE] line=79 key=935353|msmarco_passage_04_204108335 llm_relevance: '1' -> '1'
# [REPLACE] line=80 key=935353|msmarco_passage_00_564032482 llm_relevance: '1' -> '1'
# [REPLACE] line=81 key=935353|msmarco_passage_04_204109182 llm_relevance: '0' -> '0'
# [REPLACE] line=82 key=935353|msmarco_passage_63_834019925 llm_relevance: '0' -> '0'
# [REPLACE] line=83 key=935353|msmarco_passage_04_128069419 llm_relevance: '2' -> '3'
# [REPLACE] line=84 key=935353|msmarco_passage_04_216457794 llm_relevance: '1' -> '1'
# [REPLACE] line=85 key=935353|msmarco_passage_04_204109527 llm_relevance: '1' -> '1'
# [REPLACE] line=86 key=935353|msmarco_passage_05_840980212 llm_relevance: '0' -> '1'
# [REPLACE] line=87 key=935353|msmarco_passage_44_477278946 llm_relevance: '0' -> '0'
# [REPLACE] line=88 key=935353|msmarco_passage_04_216453637 llm_relevance: '2' -> '2'
# [REPLACE] line=89 key=935353|msmarco_passage_04_139960521 llm_relevance: '1' -> '1'
# [REPLACE] line=90 key=935353|msmarco_passage_04_208491547 llm_relevance: '1' -> '0'
# [REPLACE] line=91 key=935353|msmarco_passage_01_590936275 llm_relevance: '2' -> '1'
# [REPLACE] line=92 key=935353|msmarco_passage_44_477274583 llm_relevance: '1' -> '0'
# [REPLACE] line=93 key=935353|msmarco_passage_04_208493851 llm_relevance: '1' -> '1'
# [REPLACE] line=94 key=935353|msmarco_passage_04_201764545 llm_relevance: '1' -> '1'
# [REPLACE] line=95 key=935353|msmarco_passage_44_478213850 llm_relevance: '0' -> '0'
# [REPLACE] line=96 key=935353|msmarco_passage_04_208493518 llm_relevance: '0' -> '0'
# [REPLACE] line=97 key=935964|msmarco_passage_48_479279848 llm_relevance: '0' -> '0'
# [REPLACE] line=98 key=935964|msmarco_passage_66_180528267 llm_relevance: '0' -> '0'
# [REPLACE] line=99 key=935964|msmarco_passage_54_800253094 llm_relevance: '3' -> '2'
# [REPLACE] line=100 key=935964|msmarco_passage_16_12592512 llm_relevance: '0' -> '0'
# [REPLACE] line=101 key=935964|msmarco_passage_45_564087522 llm_relevance: '0' -> '0'
# [REPLACE] line=102 key=935964|msmarco_passage_11_691879317 llm_relevance: '0' -> '0'
# [REPLACE] line=103 key=935964|msmarco_passage_51_229572285 llm_relevance: '1' -> '1'
# [REPLACE] line=104 key=935964|msmarco_passage_10_380328471 llm_relevance: '1' -> '1'
# [REPLACE] line=105 key=935964|msmarco_passage_66_252210233 llm_relevance: '0' -> '1'
# [REPLACE] line=106 key=935964|msmarco_passage_31_493401056 llm_relevance: '0' -> '0'
# [REPLACE] line=107 key=935964|msmarco_passage_28_640559089 llm_relevance: '0' -> '1'
# [REPLACE] line=108 key=935964|msmarco_passage_31_792857475 llm_relevance: '0' -> '0'
# [REPLACE] line=109 key=935964|msmarco_passage_53_663304422 llm_relevance: '3' -> '2'
# [REPLACE] line=110 key=952262|msmarco_passage_48_774362860 llm_relevance: '3' -> '3'
# [REPLACE] line=111 key=952262|msmarco_passage_35_333920753 llm_relevance: '2' -> '2'
# [REPLACE] line=112 key=952262|msmarco_passage_04_375255298 llm_relevance: '1' -> '1'
# [REPLACE] line=113 key=952262|msmarco_passage_38_635539028 llm_relevance: '1' -> '1'
# [REPLACE] line=114 key=952262|msmarco_passage_57_447613267 llm_relevance: '3' -> '3'
# [REPLACE] line=115 key=952262|msmarco_passage_49_70173791 llm_relevance: '2' -> '2'
# [REPLACE] line=116 key=952262|msmarco_passage_08_217461491 llm_relevance: '0' -> '0'
# [REPLACE] line=117 key=952262|msmarco_passage_48_838301481 llm_relevance: '3' -> '3'
# [REPLACE] line=118 key=952262|msmarco_passage_59_268543239 llm_relevance: '2' -> '1'
# [REPLACE] line=119 key=952262|msmarco_passage_04_84678409 llm_relevance: '3' -> '3'
# [REPLACE] line=120 key=952262|msmarco_passage_08_61246098 llm_relevance: '2' -> '2'
# [REPLACE] line=121 key=952262|msmarco_passage_09_850150414 llm_relevance: '2' -> '2'
# [REPLACE] line=122 key=952262|msmarco_passage_44_567000444 llm_relevance: '1' -> '1'
# [REPLACE] line=123 key=952262|msmarco_passage_14_777005005 llm_relevance: '0' -> '1'
# [REPLACE] line=124 key=952262|msmarco_passage_65_827626432 llm_relevance: '0' -> '0'
# [REPLACE] line=125 key=952262|msmarco_passage_66_17360882 llm_relevance: '0' -> '0'
# [REPLACE] line=126 key=952262|msmarco_passage_24_246146361 llm_relevance: '2' -> '2'
# [REPLACE] line=127 key=952262|msmarco_passage_66_16801373 llm_relevance: '1' -> '1'
# [REPLACE] line=128 key=952262|msmarco_passage_01_804718797 llm_relevance: '3' -> '3'
# [REPLACE] line=129 key=952284|msmarco_passage_22_518472709 llm_relevance: '1' -> '1'
# [REPLACE] line=130 key=952284|msmarco_passage_27_110289987 llm_relevance: '3' -> '3'
# [REPLACE] line=131 key=952284|msmarco_passage_60_744014637 llm_relevance: '1' -> '1'
# [REPLACE] line=132 key=952284|msmarco_passage_30_524228664 llm_relevance: '1' -> '1'
# [REPLACE] line=133 key=952284|msmarco_passage_14_651423759 llm_relevance: '1' -> '1'
# [REPLACE] line=134 key=952284|msmarco_passage_52_561107099 llm_relevance: '1' -> '1'
# [REPLACE] line=135 key=952284|msmarco_passage_64_126583991 llm_relevance: '1' -> '1'
# [REPLACE] line=136 key=952284|msmarco_passage_67_106271073 llm_relevance: '1' -> '1'
# [REPLACE] line=137 key=952284|msmarco_passage_53_146496517 llm_relevance: '1' -> '1'
# [REPLACE] line=138 key=952284|msmarco_passage_22_518603800 llm_relevance: '1' -> '1'
# [REPLACE] line=139 key=952284|msmarco_passage_40_439533480 llm_relevance: '2' -> '2'
# [REPLACE] line=140 key=975079|msmarco_passage_04_377487769 llm_relevance: '1' -> '1'
# [REPLACE] line=141 key=975079|msmarco_passage_04_380377459 llm_relevance: '2' -> '2'
# [REPLACE] line=142 key=975079|msmarco_passage_04_379833081 llm_relevance: '2' -> '2'
# [REPLACE] line=143 key=975079|msmarco_passage_06_580038732 llm_relevance: '1' -> '0'
# [REPLACE] line=144 key=975079|msmarco_passage_04_379885110 llm_relevance: '0' -> '0'
# [REPLACE] line=145 key=975079|msmarco_passage_58_92711356 llm_relevance: '1' -> '1'
# [REPLACE] line=146 key=975079|msmarco_passage_01_317043704 llm_relevance: '1' -> '1'
# [REPLACE] line=147 key=975079|msmarco_passage_04_377884628 llm_relevance: '1' -> '1'
# [REPLACE] line=148 key=975079|msmarco_passage_64_236854654 llm_relevance: '0' -> '0'
# [REPLACE] line=149 key=975079|msmarco_passage_04_377603070 llm_relevance: '1' -> '1'
# [REPLACE] line=150 key=975079|msmarco_passage_04_208886763 llm_relevance: '1' -> '0'
# [REPLACE] line=151 key=975079|msmarco_passage_18_794333391 llm_relevance: '1' -> '0'
# [REPLACE] line=152 key=975079|msmarco_passage_04_380958799 llm_relevance: '2' -> '2'
# [REPLACE] line=153 key=975079|msmarco_passage_04_380033594 llm_relevance: '1' -> '1'
# [REPLACE] line=154 key=975079|msmarco_passage_58_259083082 llm_relevance: '3' -> '3'
# [REPLACE] line=155 key=975079|msmarco_passage_38_639807682 llm_relevance: '1' -> '1'
# [REPLACE] line=156 key=975079|msmarco_passage_18_485636181 llm_relevance: '0' -> '0'
# [REPLACE] line=157 key=975079|msmarco_passage_11_172121986 llm_relevance: '1' -> '1'
# [REPLACE] line=158 key=975079|msmarco_passage_68_636615833 llm_relevance: '1' -> '1'
# [REPLACE] line=159 key=1006728|msmarco_passage_22_147691478 llm_relevance: '1' -> '0'
# [REPLACE] line=160 key=1006728|msmarco_passage_07_504695154 llm_relevance: '1' -> '1'
# [REPLACE] line=161 key=1006728|msmarco_passage_28_687617757 llm_relevance: '0' -> '1'
# [REPLACE] line=162 key=1006728|msmarco_passage_28_864687853 llm_relevance: '1' -> '0'
# [REPLACE] line=163 key=1006728|msmarco_passage_04_825259357 llm_relevance: '0' -> '0'
# [REPLACE] line=164 key=1006728|msmarco_passage_51_646926876 llm_relevance: '1' -> '1'
# [REPLACE] line=165 key=1006728|msmarco_passage_55_329988089 llm_relevance: '2' -> '2'
# [REPLACE] line=166 key=1006728|msmarco_passage_26_244647406 llm_relevance: '1' -> '0'
# [REPLACE] line=167 key=1006728|msmarco_passage_05_364836294 llm_relevance: '1' -> '1'
# [REPLACE] line=168 key=1006728|msmarco_passage_33_845240529 llm_relevance: '3' -> '3'
# [REPLACE] line=169 key=1006728|msmarco_passage_30_650927429 llm_relevance: '1' -> '1'
# [REPLACE] line=170 key=1006728|msmarco_passage_17_477012949 llm_relevance: '0' -> '0'
# [REPLACE] line=171 key=1006728|msmarco_passage_19_36113644 llm_relevance: '0' -> '0'
# [REPLACE] line=172 key=1006728|msmarco_passage_21_656747181 llm_relevance: '0' -> '0'
# [REPLACE] line=173 key=1006728|msmarco_passage_55_468196767 llm_relevance: '0' -> '1'
# [REPLACE] line=174 key=1040198|msmarco_passage_52_364046568 llm_relevance: '1' -> '1'
# [REPLACE] line=175 key=1040198|msmarco_passage_67_65022544 llm_relevance: '1' -> '1'
# [REPLACE] line=176 key=1040198|msmarco_passage_67_65385584 llm_relevance: '1' -> '1'
# [REPLACE] line=177 key=1040198|msmarco_passage_67_65676063 llm_relevance: '1' -> '1'
# [REPLACE] line=178 key=1040198|msmarco_passage_16_300200839 llm_relevance: '0' -> '0'
# [REPLACE] line=179 key=1040198|msmarco_passage_58_487253591 llm_relevance: '1' -> '1'
# [REPLACE] line=180 key=1040198|msmarco_passage_00_401241303 llm_relevance: '1' -> '1'
# [REPLACE] line=181 key=1040198|msmarco_passage_16_264361861 llm_relevance: '0' -> '0'
# [REPLACE] line=182 key=1040198|msmarco_passage_32_7355814 llm_relevance: '0' -> '0'
# [REPLACE] line=183 key=1040198|msmarco_passage_42_545514224 llm_relevance: '2' -> '2'
# [REPLACE] line=184 key=1040198|msmarco_passage_32_841003200 llm_relevance: '0' -> '0'
# [REPLACE] line=185 key=1040198|msmarco_passage_00_715252919 llm_relevance: '0' -> '0'
# [REPLACE] line=186 key=1040198|msmarco_passage_16_95665947 llm_relevance: '0' -> '0'
# [REPLACE] line=187 key=1040198|msmarco_passage_39_255786236 llm_relevance: '0' -> '0'
# [REPLACE] line=188 key=1040198|msmarco_passage_10_64195837 llm_relevance: '0' -> '0'
# [REPLACE] line=189 key=1040198|msmarco_passage_63_97387931 llm_relevance: '0' -> '0'
# [REPLACE] line=190 key=1104300|msmarco_passage_39_514532327 llm_relevance: '3' -> '3'
# [REPLACE] line=191 key=1104300|msmarco_passage_12_540375302 llm_relevance: '3' -> '3'
# [REPLACE] line=192 key=1104300|msmarco_passage_29_599036822 llm_relevance: '2' -> '2'
# [REPLACE] line=193 key=1104300|msmarco_passage_12_832092606 llm_relevance: '3' -> '3'
# [REPLACE] line=194 key=1104300|msmarco_passage_12_832096704 llm_relevance: '3' -> '3'
# [REPLACE] line=195 key=1104300|msmarco_passage_40_115347772 llm_relevance: '3' -> '3'
# [REPLACE] line=196 key=1104300|msmarco_passage_29_587960871 llm_relevance: '3' -> '3'
# [REPLACE] line=197 key=1104300|msmarco_passage_02_555869908 llm_relevance: '3' -> '3'
# [REPLACE] line=198 key=1104300|msmarco_passage_29_593127088 llm_relevance: '3' -> '3'
# [REPLACE] line=199 key=1104300|msmarco_passage_22_456950510 llm_relevance: '3' -> '3'
# [REPLACE] line=200 key=1104300|msmarco_passage_35_731101872 llm_relevance: '3' -> '3'
# [REPLACE] line=201 key=1104300|msmarco_passage_11_233110103 llm_relevance: '2' -> '3'
# [REPLACE] line=202 key=1104300|msmarco_passage_68_843082660 llm_relevance: '3' -> '2'
# [REPLACE] line=203 key=1104447|msmarco_passage_30_705078065 llm_relevance: '0' -> '0'
# [REPLACE] line=204 key=1104447|msmarco_passage_09_339822431 llm_relevance: '2' -> '1'
# [REPLACE] line=205 key=1104447|msmarco_passage_45_349455569 llm_relevance: '1' -> '1'
# [REPLACE] line=206 key=1104447|msmarco_passage_30_579598183 llm_relevance: '1' -> '0'
# [REPLACE] line=207 key=1104447|msmarco_passage_02_353907708 llm_relevance: '1' -> '1'
# [REPLACE] line=208 key=1104447|msmarco_passage_28_336830624 llm_relevance: '1' -> '1'
# [REPLACE] line=209 key=1104447|msmarco_passage_39_313195563 llm_relevance: '1' -> '1'
# [REPLACE] line=210 key=1104447|msmarco_passage_05_850711058 llm_relevance: '2' -> '3'
# [REPLACE] line=211 key=1104447|msmarco_passage_44_510671468 llm_relevance: '3' -> '2'
# [REPLACE] line=212 key=1104447|msmarco_passage_04_152993504 llm_relevance: '1' -> '1'
# [REPLACE] line=213 key=1104447|msmarco_passage_30_580579463 llm_relevance: '2' -> '3'
# [REPLACE] line=214 key=1104447|msmarco_passage_38_865032892 llm_relevance: '1' -> '1'
# [REPLACE] line=215 key=1104447|msmarco_passage_22_471901875 llm_relevance: '2' -> '3'
# [REPLACE] line=216 key=1104447|msmarco_passage_57_831267725 llm_relevance: '1' -> '2'
# [REPLACE] line=217 key=1104447|msmarco_passage_04_127721315 llm_relevance: '2' -> '1'
# [REPLACE] line=218 key=1104447|msmarco_passage_32_540525539 llm_relevance: '3' -> '2'
# [REPLACE] line=219 key=1107704|msmarco_passage_59_721317266 llm_relevance: '1' -> '1'
# [REPLACE] line=220 key=1107704|msmarco_passage_43_108950340 llm_relevance: '1' -> '1'
# [REPLACE] line=221 key=1107704|msmarco_passage_04_171612499 llm_relevance: '0' -> '0'
# [REPLACE] line=222 key=1107704|msmarco_passage_69_20130280 llm_relevance: '1' -> '1'
# [REPLACE] line=223 key=1107704|msmarco_passage_18_766588368 llm_relevance: '0' -> '0'
# [REPLACE] line=224 key=1107704|msmarco_passage_18_766592446 llm_relevance: '0' -> '0'
# [REPLACE] line=225 key=1107704|msmarco_passage_43_108952456 llm_relevance: '1' -> '1'
# [REPLACE] line=226 key=1107704|msmarco_passage_01_370207387 llm_relevance: '1' -> '1'
# [REPLACE] line=227 key=1107704|msmarco_passage_07_350033830 llm_relevance: '3' -> '3'
# [REPLACE] line=228 key=1107704|msmarco_passage_51_46542865 llm_relevance: '3' -> '3'
# [REPLACE] line=229 key=1107704|msmarco_passage_30_169724599 llm_relevance: '0' -> '0'
# [REPLACE] line=230 key=1107704|msmarco_passage_04_794605440 llm_relevance: '0' -> '0'
# [REPLACE] line=231 key=1107704|msmarco_passage_41_38410875 llm_relevance: '1' -> '0'
# [REPLACE] line=232 key=1107704|msmarco_passage_07_371020197 llm_relevance: '1' -> '1'
# [REPLACE] line=233 key=1107704|msmarco_passage_51_111680912 llm_relevance: '1' -> '1'
# [REPLACE] line=234 key=1107704|msmarco_passage_08_862825781 llm_relevance: '1' -> '1'
# [REPLACE] line=235 key=1107704|msmarco_passage_29_185355146 llm_relevance: '1' -> '1'
# [REPLACE] line=236 key=1107821|msmarco_passage_20_417766454 llm_relevance: '0' -> '0'
# [REPLACE] line=237 key=1107821|msmarco_passage_30_286229076 llm_relevance: '0' -> '0'
# [REPLACE] line=238 key=1107821|msmarco_passage_22_293973489 llm_relevance: '2' -> '2'
# [REPLACE] line=239 key=1107821|msmarco_passage_20_544502347 llm_relevance: '3' -> '3'
# [REPLACE] line=240 key=1107821|msmarco_passage_18_550590180 llm_relevance: '2' -> '2'
# [REPLACE] line=241 key=1107821|msmarco_passage_19_406176885 llm_relevance: '0' -> '0'
# [REPLACE] line=242 key=1107821|msmarco_passage_19_743571751 llm_relevance: '2' -> '2'
# [REPLACE] line=243 key=1107821|msmarco_passage_67_820252284 llm_relevance: '2' -> '2'
# [REPLACE] line=244 key=1107821|msmarco_passage_20_544530081 llm_relevance: '2' -> '2'
# [REPLACE] line=245 key=1107821|msmarco_passage_15_400317724 llm_relevance: '1' -> '1'
# [REPLACE] line=246 key=1107821|msmarco_passage_13_483047477 llm_relevance: '1' -> '1'
# [REPLACE] line=247 key=1107821|msmarco_passage_18_693300794 llm_relevance: '2' -> '2'
# [REPLACE] line=248 key=1107821|msmarco_passage_19_26714410 llm_relevance: '1' -> '1'
# [REPLACE] line=249 key=1107821|msmarco_passage_00_1841950 llm_relevance: '1' -> '2'
# [REPLACE] line=250 key=1107821|msmarco_passage_20_256618485 llm_relevance: '1' -> '1'
# [REPLACE] line=251 key=1109840|msmarco_passage_46_157376529 llm_relevance: '2' -> '2'
# [REPLACE] line=252 key=1109840|msmarco_passage_55_484699237 llm_relevance: '2' -> '3'
# [REPLACE] line=253 key=1109840|msmarco_passage_57_799615970 llm_relevance: '1' -> '1'
# [REPLACE] line=254 key=1109840|msmarco_passage_57_799627385 llm_relevance: '1' -> '1'
# [REPLACE] line=255 key=1109840|msmarco_passage_57_799637637 llm_relevance: '1' -> '1'
# [REPLACE] line=256 key=1109840|msmarco_passage_06_85564116 llm_relevance: '1' -> '1'
# [REPLACE] line=257 key=1109840|msmarco_passage_31_808089037 llm_relevance: '2' -> '1'
# [REPLACE] line=258 key=1109840|msmarco_passage_50_453176684 llm_relevance: '2' -> '2'
# [REPLACE] line=259 key=1109840|msmarco_passage_45_335862880 llm_relevance: '0' -> '0'
# [REPLACE] line=260 key=1109840|msmarco_passage_19_809631093 llm_relevance: '2' -> '2'
# [REPLACE] line=261 key=1109840|msmarco_passage_27_156302563 llm_relevance: '3' -> '3'
# [REPLACE] line=262 key=1109840|msmarco_passage_00_19722921 llm_relevance: '0' -> '0'
# [REPLACE] line=263 key=1109840|msmarco_passage_42_546085691 llm_relevance: '1' -> '1'
# [REPLACE] line=264 key=1109840|msmarco_passage_01_521559528 llm_relevance: '0' -> '0'
# [REPLACE] line=265 key=1109840|msmarco_passage_24_221176005 llm_relevance: '0' -> '0'
# [REPLACE] line=266 key=1109840|msmarco_passage_16_801355629 llm_relevance: '3' -> '3'
# [REPLACE] line=267 key=1110996|msmarco_passage_12_538543645 llm_relevance: '1' -> '2'
# [REPLACE] line=268 key=1110996|msmarco_passage_12_198819174 llm_relevance: '0' -> '0'
# [REPLACE] line=269 key=1110996|msmarco_passage_23_622305877 llm_relevance: '2' -> '2'
# [REPLACE] line=270 key=1110996|msmarco_passage_60_202275507 llm_relevance: '1' -> '2'
# [REPLACE] line=271 key=1110996|msmarco_passage_60_225328704 llm_relevance: '1' -> '1'
# [REPLACE] line=272 key=1110996|msmarco_passage_26_73010684 llm_relevance: '3' -> '3'
# [REPLACE] line=273 key=1110996|msmarco_passage_06_276580941 llm_relevance: '2' -> '2'
# [REPLACE] line=274 key=1110996|msmarco_passage_29_608157610 llm_relevance: '2' -> '2'
# [REPLACE] line=275 key=1110996|msmarco_passage_30_737572032 llm_relevance: '1' -> '1'
# [REPLACE] line=276 key=1110996|msmarco_passage_02_173964114 llm_relevance: '1' -> '1'
# [REPLACE] line=277 key=1110996|msmarco_passage_15_425718829 llm_relevance: '2' -> '2'
# [REPLACE] line=278 key=1110996|msmarco_passage_37_713635908 llm_relevance: '1' -> '1'
# [REPLACE] line=279 key=1110996|msmarco_passage_06_7315083 llm_relevance: '1' -> '1'
# [REPLACE] line=280 key=1110996|msmarco_passage_60_202277207 llm_relevance: '1' -> '1'
# [REPLACE] line=281 key=1110996|msmarco_passage_60_225330799 llm_relevance: '1' -> '2'
# [REPLACE] line=282 key=1110996|msmarco_passage_00_560158369 llm_relevance: '1' -> '1'
# [REPLACE] line=283 key=1110996|msmarco_passage_28_559196041 llm_relevance: '2' -> '2'
# [REPLACE] line=284 key=1110996|msmarco_passage_30_754913887 llm_relevance: '1' -> '1'
# [REPLACE] line=285 key=1110996|msmarco_passage_21_97536492 llm_relevance: '3' -> '3'
# [REPLACE] line=286 key=1110996|msmarco_passage_26_72998590 llm_relevance: '2' -> '1'
# [REPLACE] line=287 key=1110996|msmarco_passage_45_567061541 llm_relevance: '1' -> '1'
# [REPLACE] line=288 key=1110996|msmarco_passage_30_698152607 llm_relevance: '0' -> '0'
# [REPLACE] line=289 key=1110996|msmarco_passage_01_139319134 llm_relevance: '1' -> '1'
# [REPLACE] line=290 key=1110996|msmarco_passage_11_441165721 llm_relevance: '0' -> '0'
# [REPLACE] line=291 key=1111577|msmarco_passage_05_563790299 llm_relevance: '2' -> '2'
# [REPLACE] line=292 key=1111577|msmarco_passage_43_384382367 llm_relevance: '2' -> '2'
# [REPLACE] line=293 key=1111577|msmarco_passage_06_302242293 llm_relevance: '3' -> '2'
# [REPLACE] line=294 key=1111577|msmarco_passage_05_563789830 llm_relevance: '3' -> '3'
# [REPLACE] line=295 key=1111577|msmarco_passage_43_384381898 llm_relevance: '3' -> '3'
# [REPLACE] line=296 key=1111577|msmarco_passage_18_81156006 llm_relevance: '3' -> '2'
# [REPLACE] line=297 key=1111577|msmarco_passage_01_254295856 llm_relevance: '3' -> '3'
# [REPLACE] line=298 key=1111577|msmarco_passage_22_270154705 llm_relevance: '3' -> '3'
# [REPLACE] line=299 key=1111577|msmarco_passage_39_565124980 llm_relevance: '3' -> '3'
# [REPLACE] line=300 key=1111577|msmarco_passage_06_302244060 llm_relevance: '3' -> '2'
# [REPLACE] line=301 key=1111577|msmarco_passage_53_783821943 llm_relevance: '3' -> '3'
# [REPLACE] line=302 key=1111577|msmarco_passage_30_131180116 llm_relevance: '3' -> '3'
# [REPLACE] line=303 key=1111577|msmarco_passage_30_131200137 llm_relevance: '3' -> '2'
# [REPLACE] line=304 key=1113361|msmarco_passage_30_685763627 llm_relevance: '2' -> '2'
# ...
# [REPLACE] line=2219 key=1110996|msmarco_passage_57_225980873 llm_relevance: '1' -> '1'
# [REPLACE] line=2220 key=1110996|msmarco_passage_33_621657024 llm_relevance: '1' -> '1'
# [REPLACE] line=2221 key=1110996|msmarco_passage_08_389114840 llm_relevance: '0' -> '0'
# [REPLACE] line=2222 key=1110996|msmarco_passage_55_115875048 llm_relevance: '0' -> '0'
# [REPLACE] line=2223 key=1110996|msmarco_passage_61_681928993 llm_relevance: '1' -> '2'
# [REPLACE] line=2224 key=1110996|msmarco_passage_12_198818769 llm_relevance: '3' -> '3'
# [REPLACE] line=2225 key=1110996|msmarco_passage_21_641623966 llm_relevance: '3' -> '3'
# [REPLACE] line=2226 key=1110996|msmarco_passage_21_641534379 llm_relevance: '3' -> '3'
# [REPLACE] line=2227 key=1110996|msmarco_passage_30_604452674 llm_relevance: '2' -> '3'
# [REPLACE] line=2228 key=1110996|msmarco_passage_59_57183424 llm_relevance: '3' -> '3'
# [REPLACE] line=2229 key=1110996|msmarco_passage_32_260065380 llm_relevance: '1' -> '3'
# [REPLACE] line=2230 key=1110996|msmarco_passage_26_73009819 llm_relevance: '3' -> '3'
# [REPLACE] line=2231 key=1110996|msmarco_passage_09_376603013 llm_relevance: '0' -> '1'
# [REPLACE] line=2232 key=1110996|msmarco_passage_02_566603201 llm_relevance: '3' -> '3'
# [REPLACE] line=2233 key=1110996|msmarco_passage_00_560156240 llm_relevance: '3' -> '3'
# [REPLACE] line=2234 key=1110996|msmarco_passage_00_612808760 llm_relevance: '3' -> '3'
# [REPLACE] line=2235 key=1110996|msmarco_passage_25_260066666 llm_relevance: '1' -> '1'
# [REPLACE] line=2236 key=1111577|msmarco_passage_30_131174746 llm_relevance: '1' -> '3'
# [REPLACE] line=2237 key=1111577|msmarco_passage_12_181442295 llm_relevance: '2' -> '3'
# [REPLACE] line=2238 key=1111577|msmarco_passage_04_181794401 llm_relevance: '3' -> '3'
# [REPLACE] line=2239 key=1111577|msmarco_passage_57_75279844 llm_relevance: '3' -> '3'
# [REPLACE] line=2240 key=1111577|msmarco_passage_45_771413389 llm_relevance: '3' -> '2'
# [REPLACE] line=2241 key=1111577|msmarco_passage_47_543222397 llm_relevance: '1' -> '3'
# [REPLACE] line=2242 key=1111577|msmarco_passage_57_75278708 llm_relevance: '2' -> '2'
# [REPLACE] line=2243 key=1111577|msmarco_passage_30_169971847 llm_relevance: '3' -> '3'
# [REPLACE] line=2244 key=1111577|msmarco_passage_30_131171717 llm_relevance: '3' -> '3'
# [REPLACE] line=2245 key=1111577|msmarco_passage_01_692921249 llm_relevance: '3' -> '2'
# [REPLACE] line=2246 key=1111577|msmarco_passage_25_376871867 llm_relevance: '3' -> '3'
# [REPLACE] line=2247 key=1111577|msmarco_passage_52_224642532 llm_relevance: '3' -> '3'
# [REPLACE] line=2248 key=1111577|msmarco_passage_30_131172954 llm_relevance: '3' -> '3'
# [REPLACE] line=2249 key=1111577|msmarco_passage_57_75277978 llm_relevance: '3' -> '3'
# [REPLACE] line=2250 key=1111577|msmarco_passage_30_131170422 llm_relevance: '2' -> '3'
# [REPLACE] line=2251 key=1111577|msmarco_passage_30_131168603 llm_relevance: '3' -> '3'
# [REPLACE] line=2252 key=1111577|msmarco_passage_22_234860495 llm_relevance: '3' -> '3'
# [REPLACE] line=2253 key=1111577|msmarco_passage_50_831341103 llm_relevance: '3' -> '3'
# [REPLACE] line=2254 key=1111577|msmarco_passage_01_692922353 llm_relevance: '3' -> '3'
# [REPLACE] line=2255 key=1111577|msmarco_passage_25_376872968 llm_relevance: '3' -> '3'
# [REPLACE] line=2256 key=1111577|msmarco_passage_29_617232841 llm_relevance: '3' -> '3'
# [REPLACE] line=2257 key=1111577|msmarco_passage_25_397013521 llm_relevance: '0' -> '0'
# [REPLACE] line=2258 key=1111577|msmarco_passage_26_809267999 llm_relevance: '3' -> '3'
# [REPLACE] line=2259 key=1113361|msmarco_passage_10_696317784 llm_relevance: '3' -> '3'
# [REPLACE] line=2260 key=1113361|msmarco_passage_16_95653147 llm_relevance: '3' -> '3'
# [REPLACE] line=2261 key=1113361|msmarco_passage_14_109599007 llm_relevance: '1' -> '2'
# [REPLACE] line=2262 key=1113361|msmarco_passage_28_209125286 llm_relevance: '1' -> '2'
# [REPLACE] line=2263 key=1113361|msmarco_passage_33_122464696 llm_relevance: '2' -> '3'
# [REPLACE] line=2264 key=1113361|msmarco_passage_01_758491694 llm_relevance: '3' -> '3'
# [REPLACE] line=2265 key=1113361|msmarco_passage_14_109598586 llm_relevance: '1' -> '2'
# [REPLACE] line=2266 key=1113361|msmarco_passage_15_407177357 llm_relevance: '1' -> '3'
# [REPLACE] line=2267 key=1113361|msmarco_passage_01_758492175 llm_relevance: '3' -> '3'
# [REPLACE] line=2268 key=1113361|msmarco_passage_01_758490364 llm_relevance: '1' -> '0'
# [REPLACE] line=2269 key=1113361|msmarco_passage_64_194926716 llm_relevance: '3' -> '3'
# [REPLACE] line=2270 key=1113361|msmarco_passage_15_407175499 llm_relevance: '2' -> '2'
# [REPLACE] line=2271 key=1113361|msmarco_passage_30_616567402 llm_relevance: '3' -> '2'
# [REPLACE] line=2272 key=1113361|msmarco_passage_15_407175011 llm_relevance: '1' -> '1'
# [REPLACE] line=2273 key=1113361|msmarco_passage_64_194926047 llm_relevance: '3' -> '3'
# [REPLACE] line=2274 key=1113361|msmarco_passage_02_24687249 llm_relevance: '3' -> '3'
# [REPLACE] line=2275 key=1113361|msmarco_passage_26_565835758 llm_relevance: '1' -> '3'
# [REPLACE] line=2276 key=1113361|msmarco_passage_02_24689891 llm_relevance: '3' -> '3'
# [REPLACE] line=2277 key=1113361|msmarco_passage_26_565838400 llm_relevance: '3' -> '3'
# [REPLACE] line=2278 key=1113361|msmarco_passage_33_122466742 llm_relevance: '3' -> '3'
# [REPLACE] line=2279 key=1113361|msmarco_passage_01_758487571 llm_relevance: '2' -> '2'
# [REPLACE] line=2280 key=1113361|msmarco_passage_64_194925638 llm_relevance: '2' -> '2'
# [REPLACE] line=2281 key=1113361|msmarco_passage_28_207314361 llm_relevance: '1' -> '3'
# [REPLACE] line=2282 key=1113361|msmarco_passage_52_91347567 llm_relevance: '2' -> '3'
# [REPLACE] line=2283 key=1113361|msmarco_passage_52_103225762 llm_relevance: '2' -> '3'
# [REPLACE] line=2284 key=1113361|msmarco_passage_02_24688154 llm_relevance: '3' -> '3'
# [REPLACE] line=2285 key=1113361|msmarco_passage_26_565836663 llm_relevance: '3' -> '3'
# [REPLACE] line=2286 key=1113361|msmarco_passage_64_194927232 llm_relevance: '2' -> '2'
# [REPLACE] line=2287 key=1113361|msmarco_passage_31_544615024 llm_relevance: '3' -> '3'
# [REPLACE] line=2288 key=1113361|msmarco_passage_41_660382296 llm_relevance: '3' -> '3'
# [REPLACE] line=2289 key=1113361|msmarco_passage_09_618972452 llm_relevance: '2' -> '1'
# [REPLACE] line=2290 key=1113361|msmarco_passage_61_260645694 llm_relevance: '2' -> '3'
# [REPLACE] line=2291 key=1117243|msmarco_passage_11_732991852 llm_relevance: '3' -> '3'
# [REPLACE] line=2292 key=1117243|msmarco_passage_36_414359973 llm_relevance: '2' -> '3'
# [REPLACE] line=2293 key=1117243|msmarco_passage_13_8342907 llm_relevance: '1' -> '2'
# [REPLACE] line=2294 key=1117243|msmarco_passage_33_48211830 llm_relevance: '1' -> '3'
# [REPLACE] line=2295 key=1117243|msmarco_passage_22_653310155 llm_relevance: '1' -> '3'
# [REPLACE] line=2296 key=1117243|msmarco_passage_02_363957758 llm_relevance: '2' -> '2'
# [REPLACE] line=2297 key=1117243|msmarco_passage_23_342669409 llm_relevance: '3' -> '3'
# [REPLACE] line=2298 key=1117243|msmarco_passage_35_141391298 llm_relevance: '1' -> '2'
# [REPLACE] line=2299 key=1117243|msmarco_passage_06_326098268 llm_relevance: '3' -> '3'
# [REPLACE] line=2300 key=1117243|msmarco_passage_23_342670237 llm_relevance: '1' -> '2'
# [REPLACE] line=2301 key=1117243|msmarco_passage_35_141392634 llm_relevance: '2' -> '1'
# [REPLACE] line=2302 key=1117243|msmarco_passage_64_559029609 llm_relevance: '1' -> '1'
# [REPLACE] line=2303 key=1117243|msmarco_passage_24_223390352 llm_relevance: '3' -> '3'
# [REPLACE] line=2304 key=1117243|msmarco_passage_13_8344014 llm_relevance: '3' -> '3'
# [REPLACE] line=2305 key=1117243|msmarco_passage_39_62811092 llm_relevance: '3' -> '2'
# [REPLACE] line=2306 key=1117243|msmarco_passage_10_881791455 llm_relevance: '1' -> '2'
# [REPLACE] line=2307 key=1117243|msmarco_passage_67_670537535 llm_relevance: '1' -> '2'
# [REPLACE] line=2308 key=1117243|msmarco_passage_67_383702833 llm_relevance: '1' -> '2'
# [REPLACE] line=2309 key=1117243|msmarco_passage_53_403795779 llm_relevance: '1' -> '1'
# [REPLACE] line=2310 key=1117243|msmarco_passage_55_290719375 llm_relevance: '3' -> '3'
# [REPLACE] line=2311 key=1117243|msmarco_passage_55_277808786 llm_relevance: '2' -> '3'
# [REPLACE] line=2312 key=1117243|msmarco_passage_55_290716804 llm_relevance: '1' -> '3'
# [REPLACE] line=2313 key=1117243|msmarco_passage_55_277806215 llm_relevance: '3' -> '3'
# [REPLACE] line=2314 key=1117243|msmarco_passage_35_140472097 llm_relevance: '2' -> '3'
# [REPLACE] line=2315 key=1117243|msmarco_passage_10_330843972 llm_relevance: '3' -> '3'
# [REPLACE] line=2316 key=1117243|msmarco_passage_22_635781276 llm_relevance: '3' -> '3'
# [REPLACE] line=2317 key=1117243|msmarco_passage_01_310497040 llm_relevance: '3' -> '3'
# [REPLACE] line=2318 key=1117243|msmarco_passage_01_310492187 llm_relevance: '1' -> '2'
# [REPLACE] line=2319 key=1117243|msmarco_passage_22_635776423 llm_relevance: '1' -> '2'
# [REPLACE] line=2320 key=1117243|msmarco_passage_37_509408647 llm_relevance: '1' -> '3'
# [REPLACE] line=2321 key=1117243|msmarco_passage_48_672762490 llm_relevance: '1' -> '2'
# [REPLACE] line=2322 key=1117243|msmarco_passage_32_523684556 llm_relevance: '3' -> '2'
# [REPLACE] line=2323 key=1117243|msmarco_passage_13_8345348 llm_relevance: '3' -> '3'
# [REPLACE] line=2324 key=1117243|msmarco_passage_24_128369226 llm_relevance: '1' -> '3'
# [REPLACE] line=2325 key=1117243|msmarco_passage_23_342794604 llm_relevance: '0' -> '1'
# [REPLACE] line=2326 key=1117243|msmarco_passage_23_342471482 llm_relevance: '2' -> '3'
# [REPLACE] line=2327 key=1118716|msmarco_passage_62_805891320 llm_relevance: '1' -> '2'
# [REPLACE] line=2328 key=1118716|msmarco_passage_13_70612212 llm_relevance: '1' -> '1'
# [REPLACE] line=2329 key=1118716|msmarco_passage_38_591082748 llm_relevance: '0' -> '1'
# [REPLACE] line=2330 key=1118716|msmarco_passage_03_661800358 llm_relevance: '1' -> '1'
# [REPLACE] line=2331 key=1118716|msmarco_passage_32_17192503 llm_relevance: '1' -> '1'
# [REPLACE] line=2332 key=1118716|msmarco_passage_20_738724479 llm_relevance: '1' -> '2'
# [REPLACE] line=2333 key=1118716|msmarco_passage_15_95579322 llm_relevance: '1' -> '2'
# [REPLACE] line=2334 key=1118716|msmarco_passage_38_811561620 llm_relevance: '1' -> '1'
# [REPLACE] line=2335 key=1118716|msmarco_passage_19_863525564 llm_relevance: '3' -> '3'
# [REPLACE] line=2336 key=1118716|msmarco_passage_35_218674391 llm_relevance: '0' -> '0'
# [REPLACE] line=2337 key=1118716|msmarco_passage_22_54723452 llm_relevance: '3' -> '3'
# [REPLACE] line=2338 key=1118716|msmarco_passage_05_508078172 llm_relevance: '1' -> '3'
# [REPLACE] line=2339 key=1118716|msmarco_passage_61_664046466 llm_relevance: '1' -> '1'
# [REPLACE] line=2340 key=1118716|msmarco_passage_20_738721519 llm_relevance: '1' -> '1'
# [REPLACE] line=2341 key=1118716|msmarco_passage_07_847844617 llm_relevance: '3' -> '3'
# [REPLACE] line=2342 key=1118716|msmarco_passage_32_459876976 llm_relevance: '1' -> '1'
# [REPLACE] line=2343 key=1118716|msmarco_passage_60_709560524 llm_relevance: '3' -> '3'
# [REPLACE] line=2344 key=1118716|msmarco_passage_19_863328013 llm_relevance: '3' -> '3'
# [REPLACE] line=2345 key=1118716|msmarco_passage_42_585491605 llm_relevance: '1' -> '1'
# [REPLACE] line=2346 key=1118716|msmarco_passage_22_54726837 llm_relevance: '3' -> '3'
# [REPLACE] line=2347 key=1118716|msmarco_passage_49_463390739 llm_relevance: '1' -> '1'
# [REPLACE] line=2348 key=1118716|msmarco_passage_00_786094811 llm_relevance: '1' -> '2'
# [REPLACE] line=2349 key=1118716|msmarco_passage_43_530797423 llm_relevance: '1' -> '1'
# [REPLACE] line=2350 key=1118716|msmarco_passage_33_147856716 llm_relevance: '1' -> '2'
# [REPLACE] line=2351 key=1121909|msmarco_passage_68_306305753 llm_relevance: '2' -> '0'
# [REPLACE] line=2352 key=1121909|msmarco_passage_68_306305974 llm_relevance: '3' -> '3'
# [REPLACE] line=2353 key=1121909|msmarco_passage_02_729699920 llm_relevance: '3' -> '3'
# [REPLACE] line=2354 key=1121909|msmarco_passage_01_808247906 llm_relevance: '3' -> '3'
# [REPLACE] line=2355 key=1121909|msmarco_passage_68_51864431 llm_relevance: '1' -> '1'
# [REPLACE] line=2356 key=1121909|msmarco_passage_68_306306376 llm_relevance: '0' -> '0'
# [REPLACE] line=2357 key=1121909|msmarco_passage_01_808242787 llm_relevance: '2' -> '1'
# [REPLACE] line=2358 key=1121909|msmarco_passage_01_808252200 llm_relevance: '1' -> '0'
# [REPLACE] line=2359 key=1121909|msmarco_passage_11_44498723 llm_relevance: '1' -> '1'
# [REPLACE] line=2360 key=1121909|msmarco_passage_68_51863102 llm_relevance: '1' -> '1'
# [REPLACE] line=2361 key=1121909|msmarco_passage_55_599750856 llm_relevance: '1' -> '2'
# [REPLACE] line=2362 key=1121909|msmarco_passage_11_44497847 llm_relevance: '3' -> '3'
# [REPLACE] line=2363 key=1121909|msmarco_passage_54_606456131 llm_relevance: '1' -> '0'
# [REPLACE] line=2364 key=1121909|msmarco_passage_36_164694480 llm_relevance: '1' -> '1'
# [REPLACE] line=2365 key=1121909|msmarco_passage_40_59700559 llm_relevance: '3' -> '3'
# [REPLACE] line=2366 key=1121909|msmarco_passage_53_847881865 llm_relevance: '3' -> '3'
# [REPLACE] line=2367 key=1121909|msmarco_passage_21_588021374 llm_relevance: '1' -> '1'
# [REPLACE] line=2368 key=1121909|msmarco_passage_21_588019982 llm_relevance: '2' -> '1'
# [REPLACE] line=2369 key=1121909|msmarco_passage_04_202973875 llm_relevance: '2' -> '2'
# [REPLACE] line=2370 key=1121909|msmarco_passage_68_264235915 llm_relevance: '1' -> '1'
# [REPLACE] line=2371 key=1121909|msmarco_passage_43_526272307 llm_relevance: '1' -> '3'
# [REPLACE] line=2372 key=1121909|msmarco_passage_01_739578998 llm_relevance: '1' -> '2'
# [REPLACE] line=2373 key=1121909|msmarco_passage_29_312836430 llm_relevance: '1' -> '2'
# [REPLACE] line=2374 key=1121909|msmarco_passage_29_317614290 llm_relevance: '0' -> '1'
# [REPLACE] line=2375 key=1121909|msmarco_passage_08_667548896 llm_relevance: '1' -> '1'
# [REPLACE] line=2376 key=1121909|msmarco_passage_21_570995647 llm_relevance: '3' -> '3'
# [REPLACE] line=2377 key=1121909|msmarco_passage_53_829222290 llm_relevance: '3' -> '3'
# [REPLACE] line=2378 key=1121909|msmarco_passage_32_618725185 llm_relevance: '1' -> '1'
# [REPLACE] line=2379 key=1121909|msmarco_passage_36_257721712 llm_relevance: '2' -> '3'
# [REPLACE] line=2380 key=1128632|msmarco_passage_59_209814690 llm_relevance: '2' -> '3'
# [REPLACE] line=2381 key=1128632|msmarco_passage_35_82242479 llm_relevance: '1' -> '2'
# [REPLACE] line=2382 key=1128632|msmarco_passage_59_210306861 llm_relevance: '1' -> '3'
# [REPLACE] line=2383 key=1128632|msmarco_passage_27_671736649 llm_relevance: '1' -> '3'
# [REPLACE] line=2384 key=1128632|msmarco_passage_59_208894633 llm_relevance: '1' -> '0'
# [REPLACE] line=2385 key=1128632|msmarco_passage_44_269831529 llm_relevance: '1' -> '1'
# [REPLACE] line=2386 key=1128632|msmarco_passage_16_860101278 llm_relevance: '1' -> '3'
# [REPLACE] line=2387 key=1128632|msmarco_passage_44_272802500 llm_relevance: '2' -> '3'
# [REPLACE] line=2388 key=1128632|msmarco_passage_48_63853264 llm_relevance: '2' -> '3'
# [REPLACE] line=2389 key=1128632|msmarco_passage_48_65404793 llm_relevance: '2' -> '3'
# [REPLACE] line=2390 key=1128632|msmarco_passage_48_65415033 llm_relevance: '2' -> '3'
# [REPLACE] line=2391 key=1128632|msmarco_passage_48_69765488 llm_relevance: '2' -> '3'
# [REPLACE] line=2392 key=1128632|msmarco_passage_51_133660371 llm_relevance: '2' -> '3'
# [REPLACE] line=2393 key=1128632|msmarco_passage_51_133669391 llm_relevance: '2' -> '3'
# [REPLACE] line=2394 key=1128632|msmarco_passage_59_209817211 llm_relevance: '2' -> '3'
# [REPLACE] line=2395 key=1128632|msmarco_passage_59_208055204 llm_relevance: '1' -> '2'
# [REPLACE] line=2396 key=1128632|msmarco_passage_35_708981366 llm_relevance: '0' -> '0'
# [DONE replace] replaced=2395 kept=0 appended_new=0 preserved_old_llm=6 key_cols=('qid','pid') file=outputs\llm_label\trec_dl_2021\qwen3-32b-v1\qwen3-32b-v1_trecdl_2021_thcwb_labels.csv
# [DONE] Model: qwen.qwen3-32b-v1:0 | Rows: 2549 | Combined: outputs\llm_label\trec_dl_2021\qwen3-32b-v1\qwen3-32b-v1_trecdl_2021_thcwb_labels.csv
# [TOKENS] in=1,159,906 out=45,479 total=1,205,385
# [CLEANUP] Removed temp folder: outputs\llm_label\trec_dl_2021\qwen3-32b-v1\_tmp_20260331_170240_qwen.qwen3-32b-v1_0_thcwb
# [RUNNER] Finished language=thcwb
